# %% [markdown]
# Python is a popular programming language. It was majorly used on servers to create and manage the web applications. After the AI, Python literally became a important language to study.
#
# The usual cliche informations are  :
# - It is created by Guido van Rossum in 1991
# - The main reason it became popular is that it works on various platform and the syntax is mostly english.
#
# To Get started, Install python and Any IDE

# %% [markdown]
# <b> PYTHON SYNTAX : </b>
#
#
# Python syntax can be executed directly in the terminal or creating a python file (.py) and running it

# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# <b>PYTHON INTENDATION : </b>
#
#
# Intendation refers to the spaces in the code line. In other language, the intendation in code is for readability but in python it's very important. Python uses intendations to indicate a block of code.

# %%
number = 5
if number > 0:
    print("Positive number")
# Out:
# Positive number

# %% [markdown]
# <b> COMMENTS: </b>
#
#
# python has a commenting ability for the purpose of in-code documentation. Comments can be implemented with the # (hashtags) or '''' (multiline comments)

# %%
# This is a single line comment
''' This is a multiline comment
    that spans multiple lines '''

# %% [markdown]
# <b> PYTHON STATEMENTS : </b>
#
#
# A computer program is a list of instructions to be executed by a computer. The programming instructions are called Statements.
# In python, a statement usually ends when the line ends, we don't need a semicolon like other languages. But we can do this,

# %%
print ("Hello world"); print("Welcome to Python")

# %% [markdown]
# <b> PYTHON OUTPUT : </b>
#
#
# we use the print() function to print the text and numbers in the code. We also can do math operations inside the print statements. Python outputs have various features and functions. we can clearly use it for lot of stuffs.

# %%
print("Hello world"); print(10+13)
